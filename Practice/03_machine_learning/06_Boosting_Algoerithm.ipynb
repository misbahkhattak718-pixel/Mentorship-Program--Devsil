# %% [markdown]
# # Bossting Algoerithm:

# %%
# import libraries is basic and using in Boosting Algoerithm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics
from  sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder

# %%
# load the 'iris' dataset:
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# split the dataset X and y:

X = df.drop('species', axis=1)
y = df['species']

# %%
# encode the target variable:
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# split the train and test data:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# train the decision tree model:
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# predict the test data:
y_pred = model.predict(X_test)

# Evaluate the model:
print('Accuracy_score:', accuracy_score(y_test, y_pred))        
print('precision_score:', metrics.precision_score(y_test, y_pred, average='macro'))
print('recall_score:', metrics.recall_score(y_test, y_pred, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy_score: 1.0
# precision_score: 1.0
# recall_score: 1.0
# f1_score: 1.0

# %%
# train the random forest model:
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train) 

# evaluate the model:
y_pred = model.predict(X_test)
print('Accuracy_score:', accuracy_score(y_test, y_pred))        
print('precision_score:', metrics.precision_score(y_test, y_pred, average='macro'))
print('recall_score:', metrics.recall_score(y_test, y_pred, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy_score: 1.0
# precision_score: 1.0
# recall_score: 1.0
# f1_score: 1.0

# %%
# train the xgboost model:
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)

# predicte the test data:
y_pred = xgb.predict(X_test)

# Evaluate the model:
print('Accuracy_score:', accuracy_score(y_test, y_pred))        
print('precision_score:', metrics.precision_score(y_test, y_pred, average='macro'))
print('recall_score:', metrics.recall_score(y_test, y_pred, average='macro'))
print('f1_score:', metrics.f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy_score: 1.0
# precision_score: 1.0
# recall_score: 1.0
# f1_score: 1.0

# %%
# import the of recall and f1_score library
from sklearn.metrics import recall_score, f1_score

# %%
# make the bar  plot showing each of the matrix with respect to the model:
from matplotlib import pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# # CatBoost Algoorithm:

# %%
catboost is a boosting algorithm that is used for classification 
and regression problems. It is a tree-based model that uses a gradient
boosting algorithm to train the model.

# %%
pip istall catboost
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "istall" - maybe you meant "install"

# %%
#  import libreries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics
from  sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder
from catboost import CatBoostRegressor

# %%
# load the 'titanic' dataset:
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# prepprocessing the data:
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# imput the missing values in age and fare:
df['age'].fillna(df['age'].median(), inplace=True)
df['fare'].fillna(df['fare'].median(), inplace=True)
df['deck'].fillna('C', inplace=True)
# impute the missing values in embarked and embark_town:
df['embarked'].fillna('S', inplace=True)
df['embark_town'].fillna('Southampton', inplace=True)
df.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12164\1618878204.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12164\1618878204.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
 df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
#  convert the category columns to category:
category_col = df.select_dtypes(include=['object','category']).columns

# add this a new column in the dataframe:
df[category_col] = df[category_col].astype('category')

# %%
# split the data into X and y:
X = df.drop('survived', axis=1)
y = df['survived']

# split the data into train and test:

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# run the catboost classfier:
model = CatBoostRegressor(iterations=1000, 
                           learning_rate=0.1,
                           depth=3,
                           loss_function='RMSE',
                           random_seed=42,
                           eval_metric='RMSE')

# %%
#  train the model:
model.fit(X_train, y_train,cat_features=category_col.tolist()) 

# predict the test data:
y_pred = model.predict(X_test)
# evaluate the model:
print('Accuracy_score:', accuracy_score(y_test, y_pred))        
print('confusion_matrix:', confusion_matrix(y_test, y_pred))
print('classification_report:', classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.4375060	total: 19.6ms	remaining: 19.6s
# 1:	learn: 0.3953073	total: 30.8ms	remaining: 15.4s
# 2:	learn: 0.3561524	total: 38.5ms	remaining: 12.8s
# 3:	learn: 0.3208763	total: 46.9ms	remaining: 11.7s
# 4:	learn: 0.2896759	total: 100ms	remaining: 20s
# 5:	learn: 0.2613540	total: 137ms	remaining: 22.7s
# 6:	learn: 0.2360941	total: 153ms	remaining: 21.7s
# 7:	learn: 0.2131452	total: 177ms	remaining: 22s
# 8:	learn: 0.1922367	total: 216ms	remaining: 23.8s
# 9:	learn: 0.1735937	total: 228ms	remaining: 22.5s
# 10:	learn: 0.1568731	total: 296ms	remaining: 26.7s
# 11:	learn: 0.1413478	total: 305ms	remaining: 25.1s
# 12:	learn: 0.1276907	total: 323ms	remaining: 24.5s
# 13:	learn: 0.1152776	total: 365ms	remaining: 25.7s
# 14:	learn: 0.1041082	total: 380ms	remaining: 25s
# 15:	learn: 0.0940942	total: 395ms	remaining: 24.3s
# 16:	learn: 0.0850476	total: 409ms	remaining: 23.6s
# 17:	learn: 0.0767497	total: 419ms	remaining: 22.8s
# 18:	learn: 0.0692497	total: 429ms	remaining: 22.1s
# ...
