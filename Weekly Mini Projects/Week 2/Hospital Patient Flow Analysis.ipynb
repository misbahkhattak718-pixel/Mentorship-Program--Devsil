# %% [markdown]
# *****Hospital Patient Flow Analysis:*****

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
from io import StringIO

# %% [markdown]
# ***- Create or load a relevant dataset in CSV format:***

# %%
patient_data="""patient_name,patient_id,Admission_data,department,age,wait_time_hours,treatment_time_hours,discharge_statas
MISBAH KHATTAK,301,2025-12-1,Emergency,21,00.00,04.00,Adimtted
NOMAN KHAN,302,2025-12-4,SURGERY,23,04.00,05.00,discharge
m.Qasim,303,2025-12-3,Pediatrics,26,05,03.00,Adimtted 
Tohid khan,304,2025-12-7,Emergency,28,02.00,02.00,discharge
Israr khan,305,2025-12-12,Internal Medicine,45,01.00,03.00,discharge """

df = pd.read_csv(StringIO(patient_data), parse_dates=['Admission_data'])
df
# Out:
#      patient_name  patient_id Admission_data         department  age  \
# 0  MISBAH KHATTAK         301     2025-12-01          Emergency   21
# 1      NOMAN KHAN         302     2025-12-04            SURGERY   23
# 2         m.Qasim         303     2025-12-03         Pediatrics   26
# 3      Tohid khan         304     2025-12-07          Emergency   28
# 4      Israr khan         305     2025-12-12  Internal Medicine   45
#
#    wait_time_hours  treatment_time_hours discharge_statas
# 0              0.0                   4.0         Adimtted
# 1              4.0                   5.0        discharge
# 2              5.0                   3.0        Adimtted
# 3              2.0                   2.0        discharge
# 4              1.0                   3.0       discharge

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patient_name          5 non-null      object
#  1   patient_id            5 non-null      int64
#  2   Admission_data        5 non-null      datetime64[ns]
#  3   department            5 non-null      object
#  4   age                   5 non-null      int64
#  5   wait_time_hours       5 non-null      float64
#  6   treatment_time_hours  5 non-null      float64
#  7   discharge_statas      5 non-null      object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 452.0+ bytes

# %%
df.head()
# Out:
#      patient_name  patient_id Admission_data         department  age  \
# 0  MISBAH KHATTAK         301     2025-12-01          Emergency   21
# 1      NOMAN KHAN         302     2025-12-04            SURGERY   23
# 2         m.Qasim         303     2025-12-03         Pediatrics   26
# 3      Tohid khan         304     2025-12-07          Emergency   28
# 4      Israr khan         305     2025-12-12  Internal Medicine   45
#
#    wait_time_hours  treatment_time_hours discharge_statas
# 0              0.0                   4.0         Adimtted
# 1              4.0                   5.0        discharge
# 2              5.0                   3.0        Adimtted
# 3              2.0                   2.0        discharge
# 4              1.0                   3.0       discharge

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      patient_name  patient_id Admission_data         department  age  \
# 0  MISBAH KHATTAK         301     2025-12-01          Emergency   21
# 1      NOMAN KHAN         302     2025-12-04            SURGERY   23
# 2         m.Qasim         303     2025-12-03         Pediatrics   26
# 3      Tohid khan         304     2025-12-07          Emergency   28
# 4      Israr khan         305     2025-12-12  Internal Medicine   45
#
#    wait_time_hours  treatment_time_hours discharge_statas
# 0              0.0                   4.0         Adimtted
# 1              4.0                   5.0        discharge
# 2              5.0                   3.0        Adimtted
# 3              2.0                   2.0        discharge
# 4              1.0                   3.0       discharge   >

# %%
df.shape
# Out:
# (5, 8)

# %%
df.columns
# Out:
# Index(['patient_name', 'patient_id', 'Admission_data', 'department', 'age',
#        'wait_time_hours', 'treatment_time_hours', 'discharge_statas'],
#       dtype='object')

# %%
df['department'].unique()
# Out:
# array(['Emergency', 'SURGERY', 'Pediatrics', 'Internal Medicine'],
#       dtype=object)

# %%
df['department'].unique().sum()
# Out:
# 'EmergencySURGERYPediatricsInternal Medicine'

# %%
df['department'].nunique()
# Out:
# 4

# %%
df['Admission_data'].nunique()
# Out:
# 5

# %% [markdown]
# ***- Inspect and clean the data using Pandas:***

# %%
df.isnull().sum()
# Out:
# patient_name            0
# patient_id              0
# Admission_data          0
# department              0
# age                     0
# wait_time_hours         0
# treatment_time_hours    0
# discharge_statas        0
# dtype: int64

# %% [markdown]
# ***- Perform basic statistical analysis (mean, min, max):***

# %%
df[ 'wait_time_hours'].mean()
# Out:
# np.float64(2.4)

# %%
df['wait_time_hours'].max()
# Out:
# np.float64(5.0)

# %%
df['wait_time_hours'].min()
# Out:
# np.float64(0.0)

# %% [markdown]
# ***- Create at least one meaningful visualization:***

# %%
fig = px.scatter(df,x='department',y='wait_time_hours',title='Patient Wait Times by Department (hours)',color='department')
fig

# %%
fig = px.scatter(df,x='department',y='treatment_time_hours',title='Patient Wait Times by Department (hours)',color='department')
fig

# %%
fig = px.bar(df,x='department',y='treatment_time_hours',title='Patient Wait Times by Department (hours)',color='department')
fig

# %%
fig = px.box(df,x='department',y='treatment_time_hours',title='Patient Wait Times by Department (hours)',color='department')
fig

# %%
fig = px.line(df,x='department',y='treatment_time_hours',title='Patient Wait Times by Department (hours)',color='department')
fig
