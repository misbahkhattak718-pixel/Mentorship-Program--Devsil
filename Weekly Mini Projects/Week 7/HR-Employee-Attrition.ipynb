# %% [markdown]
# <div style="background-color:#FAF3F3; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #E57373; margin-top: 20px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#D32F2F; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Exploratory Data Analysis and Machine Learning on HR-Employee-Attrition
#     </h1>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Employee Attrition Project Plan</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 20px;
#             background-color: #f5f7fa;
#         }
#         h2 {
#             text-align: center;
#             color: #2c3e50;
#         }
#         table {
#             width: 100%;
#             border-collapse: collapse;
#             margin-top: 20px;
#             background-color: #ffffff;
#         }
#         th, td {
#             border: 1px solid #ddd;
#             padding: 10px;
#             text-align: left;
#         }
#         th {
#             background-color: #2c3e50;
#             color: white;
#         }
#         tr:nth-child(even) {
#             background-color: #f2f2f2;
#         }
#         tr:hover {
#             background-color: #e6f2ff;
#         }
#     </style>
# </head>
# <body>
#
# <h2>Employee Attrition Analysis Project Plan</h2>
#
# <table>
#     <tr>
#         <th>Phase</th>
#         <th>Step No.</th>
#         <th>Task</th>
#         <th>Description</th>
#         <th>Tools / Techniques</th>
#         <th>Output</th>
#     </tr>
#     <!-- Data Cleaning -->
#     <tr>
#         <td rowspan="5">Data Cleaning & Preprocessing</td>
#         <td>1.1</td>
#         <td>Handle Missing Values</td>
#         <td>Identify and treat missing/null values using imputation or removal</td>
#         <td>Pandas (isnull, fillna)</td>
#         <td>Clean dataset</td>
#     </tr>
#     <tr>
#         <td>1.2</td>
#         <td>Remove Duplicates</td>
#         <td>Detect and drop duplicate records</td>
#         <td>Pandas (drop_duplicates)</td>
#         <td>Unique records</td>
#     </tr>
#     <tr>
#         <td>1.3</td>
#         <td>Encode Categorical Variables</td>
#         <td>Convert categorical data into numerical format</td>
#         <td>Label Encoding / One-Hot Encoding</td>
#         <td>Model-ready data</td>
#     </tr>
#     <tr>
#         <td>1.4</td>
#         <td>Feature Scaling</td>
#         <td>Normalize/standardize numerical features</td>
#         <td>StandardScaler / MinMaxScaler</td>
#         <td>Scaled dataset</td>
#     </tr>
#     <tr>
#         <td>1.5</td>
#         <td>Outlier Detection</td>
#         <td>Identify and handle extreme values</td>
#         <td>Boxplot, IQR, Z-score</td>
#         <td>Refined dataset</td>
#     </tr>
#     <!-- EDA -->
#     <tr>
#         <td rowspan="6">Exploratory Data Analysis (EDA)</td>
#         <td>2.1</td>
#         <td>Attrition Distribution</td>
#         <td>Analyze proportion of employees leaving vs staying</td>
#         <td>Countplot, Pie chart</td>
#         <td>Attrition insights</td>
#     </tr>
#     <tr>
#         <td>2.2</td>
#         <td>Salary vs Attrition</td>
#         <td>Examine salary impact on attrition</td>
#         <td>Boxplot, Bar chart</td>
#         <td>Salary trends</td>
#     </tr>
#     <tr>
#         <td>2.3</td>
#         <td>Job Satisfaction vs Attrition</td>
#         <td>Study satisfaction levels vs attrition</td>
#         <td>Group analysis, Visualization</td>
#         <td>Behavioral insights</td>
#     </tr>
#     <tr>
#         <td>2.4</td>
#         <td>Correlation Heatmap</td>
#         <td>Identify relationships between variables</td>
#         <td>Seaborn Heatmap</td>
#         <td>Feature relationships</td>
#     </tr>
#     <tr>
#         <td>2.5</td>
#         <td>Distribution Analysis</td>
#         <td>Analyze data spread and skewness</td>
#         <td>Histogram, KDE Plot</td>
#         <td>Data distribution</td>
#     </tr>
#     <tr>
#         <td>2.6</td>
#         <td>Pattern Identification</td>
#         <td>Extract key trends and insights</td>
#         <td>Visual + Statistical Analysis</td>
#         <td>Business insights</td>
#     </tr>
#     <!-- Statistical Analysis -->
#     <tr>
#         <td rowspan="4">Statistical Analysis</td>
#         <td>3.1</td>
#         <td>Descriptive Statistics</td>
#         <td>Calculate mean, median, standard deviation</td>
#         <td>Pandas describe()</td>
#         <td>Summary statistics</td>
#     </tr>
#     <tr>
#         <td>3.2</td>
#         <td>Hypothesis Testing</td>
#         <td>Compare salary between attrition groups</td>
#         <td>T-test / ANOVA</td>
#         <td>Statistical significance</td>
#     </tr>
#     <tr>
#         <td>3.3</td>
#         <td>Confidence Intervals</td>
#         <td>Estimate range of population parameters</td>
#         <td>Statistical formulas</td>
#         <td>Reliability measure</td>
#     </tr>
#     <tr>
#         <td>3.4</td>
#         <td>Correlation Analysis</td>
#         <td>Measure variable relationships</td>
#         <td>Pearson/Spearman</td>
#         <td>Correlation values</td>
#     </tr>
#     <!-- Machine Learning -->
#     <tr>
#         <td rowspan="5">Machine Learning Models</td>
#         <td>4.1</td>
#         <td>Logistic Regression</td>
#         <td>Build baseline classification model</td>
#         <td>Scikit-learn</td>
#         <td>Predictions</td>
#     </tr>
#     <tr>
#         <td>4.2</td>
#         <td>Decision Tree</td>
#         <td>Create tree-based model</td>
#         <td>DecisionTreeClassifier</td>
#         <td>Model rules</td>
#     </tr>
#     <tr>
#         <td>4.3</td>
#         <td>Random Forest</td>
#         <td>Ensemble learning for better accuracy</td>
#         <td>RandomForestClassifier</td>
#         <td>Improved predictions</td>
#     </tr>
#     <tr>
#         <td>4.4</td>
#         <td>SVM</td>
#         <td>Classification using hyperplanes</td>
#         <td>SVC</td>
#         <td>Optimized separation</td>
#     </tr>
#     <tr>
#         <td>4.5</td>
#         <td>KNN</td>
#         <td>Distance-based classification</td>
#         <td>KNeighborsClassifier</td>
#         <td>Neighbor predictions</td>
#     </tr>
#     <!-- Evaluation -->
#     <tr>
#         <td rowspan="7">Model Evaluation</td>
#         <td>5.1</td>
#         <td>Accuracy</td>
#         <td>Measure overall correctness</td>
#         <td>accuracy_score</td>
#         <td>Performance metric</td>
#     </tr>
#     <tr>
#         <td>5.2</td>
#         <td>Precision</td>
#         <td>Evaluate false positives</td>
#         <td>precision_score</td>
#         <td>Classification quality</td>
#     </tr>
#     <tr>
#         <td>5.3</td>
#         <td>Recall</td>
#         <td>Evaluate false negatives</td>
#         <td>recall_score</td>
#         <td>Sensitivity</td>
#     </tr>
#     <tr>
#         <td>5.4</td>
#         <td>F1 Score</td>
#         <td>Balance precision and recall</td>
#         <td>f1_score</td>
#         <td>Combined metric</td>
#     </tr>
#     <tr>
#         <td>5.5</td>
#         <td>Confusion Matrix</td>
#         <td>Visualize prediction results</td>
#         <td>confusion_matrix</td>
#         <td>Error analysis</td>
#     </tr>
#     <tr>
#         <td>5.6</td>
#         <td>ROC-AUC Curve</td>
#         <td>Evaluate classification performance</td>
#         <td>roc_auc_score</td>
#         <td>Model comparison</td>
#     </tr>
#     <tr>
#         <td>5.7</td>
#         <td>Cross Validation</td>
#         <td>Ensure model stability</td>
#         <td>K-Fold Cross Validation</td>
#         <td>Reliable results</td>
#     </tr>
#
# </table>
#
# </body>
# </html>

# %% [markdown]
# ### Project Description: Employee Attrition Analysis
#
# ***🔷 1. Methodology***
#
# The project follows a structured data science pipeline to analyze and predict employee attrition:
#
# Step 1: Data Collection
#
# Dataset contains employee-related information such as demographics, job role, salary, and satisfaction levels.
#
# Step 2: Data Cleaning & Preprocessing
#
# Handle missing values using imputation techniques.
#
# Remove duplicate records to ensure data quality.
#
# Encode categorical variables (e.g., Gender, JobRole).
#
# Apply feature scaling (StandardScaler / MinMaxScaler).
#
# Detect and treat outliers using IQR or Z-score methods.
#
# Step 3: Exploratory Data Analysis (EDA)
#
# Analyze attrition distribution (Yes/No).
#
# Study relationships:
#
# Salary vs Attrition
#
# Job Satisfaction vs Attrition
#
# Generate correlation heatmap.
#
# Plot distributions (histograms, boxplots).
#
# Identify trends and patterns affecting attrition.
#
# Step 4: Statistical Analysis
#
# Compute descriptive statistics (mean, median, std deviation).
#
# Perform hypothesis testing (e.g., salary difference between attrition groups).
#
# Calculate confidence intervals.
#
# Conduct correlation analysis between variables.
#
# Step 5: Model Building
#
# Train multiple machine learning models:
#
# Logistic Regression
#
# Decision Tree
#
# Random Forest
#
# Support Vector Machine (SVM)
#
# K-Nearest Neighbors (KNN)
#
# Step 6: Model Evaluation
#
# Evaluate models using:
#
# Accuracy
#
# Precision
#
# Recall
#
# F1 Score
#
# Confusion Matrix
#
# ROC-AUC Curve
#
# Cross-validation
#
# Step 7: Model Comparison & Selection
#
# Compare performance metrics.
#
# Select the best-performing model for prediction.
#
#
#
# ***🔷 2. Assumptions***
#
# The dataset is accurate and representative of real employee data.
#
# No major bias or missing critical variables.
#
# Attrition depends on measurable factors such as:
#
# Salary
#
# Job satisfaction
#
# Work-life balance
#
# Features are assumed to be independent (for some models like Logistic Regression).
#
# Historical patterns can predict future attrition behavior.
#
# ***🔷 3. Scope of the Project
# In Scope:***
#
# Identify key factors influencing employee attrition.
#
# Build predictive models for attrition.
#
# Provide insights for HR decision-making.
#
# Out of Scope:
#
# Real-time prediction systems.
#
# External factors (e.g., economy, personal issues).
#
# Deep learning models (not required here).
#
# Applications:
#
# HR analytics
#
# Employee retention strategies
#
# Workforce planning
#
#
# ---
#
#
#
# | **Feature Name**         | **Description**                     | **Data Type** |
# | ------------------------ | ----------------------------------- | ------------- |
# | Age                      | Employee age                        | Numeric       |
# | Attrition                | Whether employee left (Yes/No)      | Categorical   |
# | BusinessTravel           | Travel frequency                    | Categorical   |
# | DailyRate                | Daily salary rate                   | Numeric       |
# | Department               | Department name                     | Categorical   |
# | DistanceFromHome         | Distance from home to office        | Numeric       |
# | Education                | Education level (1–5)               | Numeric       |
# | EducationField           | Field of education                  | Categorical   |
# | EmployeeCount            | Count of employees (constant)       | Numeric       |
# | EmployeeNumber           | Unique employee ID                  | Numeric       |
# | EnvironmentSatisfaction  | Work environment satisfaction (1–4) | Numeric       |
# | Gender                   | Male/Female                         | Categorical   |
# | HourlyRate               | Hourly wage                         | Numeric       |
# | JobInvolvement           | Job involvement level (1–4)         | Numeric       |
# | JobLevel                 | Job level (1–5)                     | Numeric       |
# | JobRole                  | Employee job role                   | Categorical   |
# | JobSatisfaction          | Satisfaction level (1–4)            | Numeric       |
# | MaritalStatus            | Marital status                      | Categorical   |
# | MonthlyIncome            | Monthly salary                      | Numeric       |
# | MonthlyRate              | Monthly rate                        | Numeric       |
# | NumCompaniesWorked       | Number of companies worked          | Numeric       |
# | Over18                   | Age above 18 (Y/N)                  | Categorical   |
# | OverTime                 | Works overtime (Yes/No)             | Categorical   |
# | PercentSalaryHike        | Salary hike percentage              | Numeric       |
# | PerformanceRating        | Performance score                   | Numeric       |
# | RelationshipSatisfaction | Relationship satisfaction (1–4)     | Numeric       |
# | StandardHours            | Standard working hours              | Numeric       |
# | StockOptionLevel         | Stock option level                  | Numeric       |
# | TotalWorkingYears        | Total experience years              | Numeric       |
# | TrainingTimesLastYear    | Trainings attended                  | Numeric       |
# | WorkLifeBalance          | Work-life balance rating (1–4)      | Numeric       |
# | YearsAtCompany           | Years in company                    | Numeric       |
# | YearsInCurrentRole       | Years in current role               | Numeric       |
# | YearsSinceLastPromotion  | Years since last promotion          | Numeric       |
# | YearsWithCurrManager     | Years with current manager          | Numeric       |
#
#
#
# ---
