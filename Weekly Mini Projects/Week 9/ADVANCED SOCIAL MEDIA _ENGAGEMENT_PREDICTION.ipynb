# %% [markdown]
# <div style="background-color:#FAF3F3; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #E57373; margin-top: 20px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#D32F2F; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Exploratory Data Analysis and Machine Learning on ADVANCED SOCIAL
#          MEDIA ENGAGEMENT PREDICTION
#     </h1>
# </div>

# %% [markdown]
# <div style="background-color:#E6F9E6; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 20px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#4A90E2; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         About Author
#     </h1>
#     <div style="text-align:center;">
#         <a href="https://misbah.devsil.com/">
#             <img src="https://misbah.devsil.com/assets/images/picture%20misbah.png" style="width: 20%; border-radius: 50%;" alt="Misbah Khattak">
#         </a>
#     </div>
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333; text-align:center;">Mr. Misbah Khattak</h2>
#     <p style="font-size:16px; font-family:Georgia, serif; line-height: 1.5em; text-align:center; color:#333;">
#         <em>Data Scientist / AI Engineer</em><br>
#         BS Computer Science
#     </p>
#     <div style="text-align:center; margin-top: 10px;">
#         <a href="https://www.linkedin.com/mynetwork/grow/">
#             <img width="50" height="50" src="https://img.icons8.com/color/48/linkedin.png" alt="linkedin">
#         </a>
#         <a href="https://github.com/misbahkhattak718-pixel?tab=repositories">
#             <img width="50" height="50" src="https://img.icons8.com/ios-glyphs/50/github.png" alt="github">
#         </a>
#         <a href="https://www.kaggle.com/misbahkhattak123">
#             <img width="50" height="50" src="https://img.icons8.com/clouds/100/kaggle.png" alt="kaggle">
#         </a>
#     </div>
#     <div style="text-align:center; margin-top: 20px;">
#         <a href="https://misbah.devsil.com/" style="font-size:18px; font-family:Georgia, serif; color:#4A90E2; text-decoration:none; border:2px solid #4A90E2; padding: 5px 15px; border-radius: 5px;">
#             Portfolio Site
#         </a>
#     </div>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Project Table of Contents</title>
#     <!-- Bootstrap 5 CDN -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet">
#     <style>
#         body {
#             background-color: #f8f9fa;
#         }
#         .table-container {
#             margin-top: 50px;
#         }
#         h2 {
#             font-weight: bold;
#             color: #343a40;
#         }
#         .card {
#             border-radius: 15px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="container table-container">
#     <div class="card shadow p-4">
#         <h2 class="text-center mb-4"> Project Table of Contents</h2>
#         <div class="table-responsive">
#             <table class="table table-hover table-bordered align-middle">
#                 <thead class="table-dark text-center">
#                     <tr>
#                         <th>Section No.</th>
#                         <th>Section Title</th>
#                         <th>Description</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td class="text-center">1</td>
#                         <td><strong>Data Understanding and Exploration</strong></td>
#                         <td>Load dataset, inspect structure, analyze data types, detect missing values, and perform descriptive statistics.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">2</td>
#                         <td><strong>Exploratory Data Analysis (EDA)</strong></td>
#                         <td>Visualize engagement distributions, platform comparisons, campaign phase analysis, and correlation heatmaps.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">3</td>
#                         <td><strong>Data Preprocessing</strong></td>
#                         <td>Handle missing values, remove outliers (IQR), encode categorical variables, and apply scaling techniques.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">4</td>
#                         <td><strong>Feature Engineering</strong></td>
#                         <td>Create total engagement, extract time-based features, count hashtags/mentions, and use sentiment features.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">5</td>
#                         <td><strong>Machine Learning Models</strong></td>
#                         <td>Train models such as Linear Regression, Logistic Regression, KNN, Decision Tree, Random Forest, Naive Bayes, and SVM.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">6</td>
#                         <td><strong>Ensemble and Advanced Models</strong></td>
#                         <td>Apply Random Forest, XGBoost, CatBoost, and boosting techniques for improved performance.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">7</td>
#                         <td><strong>Model Optimization</strong></td>
#                         <td>Perform hyperparameter tuning, cross-validation, pipeline implementation, and best model selection.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">8</td>
#                         <td><strong>Unsupervised Learning</strong></td>
#                         <td>Apply clustering methods such as K-Means, Hierarchical Clustering, DBSCAN, and GMM.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">9</td>
#                         <td><strong>Dimensionality Reduction</strong></td>
#                         <td>Use PCA, SVD, and t-SNE for reducing dimensionality and visualization.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">10</td>
#                         <td><strong>Deep Learning Extension (Optional)</strong></td>
#                         <td>Build a neural network using TensorFlow or Keras to predict engagement rate.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">11</td>
#                         <td><strong>Model Evaluation</strong></td>
#                         <td>Evaluate models using Accuracy, Precision, Recall, F1-score, and RMSE.</td>
#                     </tr>
#                     <tr>
#                         <td class="text-center">12</td>
#                         <td><strong>Final Deliverables</strong></td>
#                         <td>Submit notebook, cleaned dataset, visualizations, models, comparisons, optimized model, and final report.</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#     </div>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 15px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 15px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#          Introduction
#     </h1>
# </div>

# %% [markdown]
# ### Project Introduction
#
# This project focuses on analyzing social media engagement data to understand how users interact with different brands, products, and campaigns. The dataset contains information from platforms like Instagram, Twitter, Reddit, and YouTube.
#
# The main goal is to use data analysis and machine learning techniques to find patterns in user behavior, sentiment, and engagement, and to predict engagement rates.
#
# ### Project Description
#
# In this project, we:
#
# Analyze how users react to different products and campaigns
# Study engagement metrics like likes, shares, comments, and impressions
# Explore how sentiment (positive/negative) affects engagement
# Build machine learning models to predict engagement rate
# Compare different models to find the best-performing one
#
# This project helps businesses understand customer behavior and improve marketing strategies.
#
# ### Dataset Description
#
# The dataset contains social media posts with multiple features:
#
# ### Basic Information
#
#
# | **Category**           | **Feature Name**            | **Description**                                                       |
# | ---------------------- | --------------------------- | --------------------------------------------------------------------- |
# | **Basic Info**         | **post_id**                 | Unique identifier for each social media post                          |
# |                        | **timestamp**               | Date and time when the post was created                               |
# |                        | **day_of_week**             | Day of the week (Monday–Sunday)                                       |
# |                        | **platform**                | Platform used (Instagram, Twitter, Reddit, YouTube)                   |
# |                        | **user_id**                 | Unique ID of the user who posted                                      |
# |                        | **location**                | Geographic location of the user                                       |
# |                        | **language**                | Language in which the post is written                                 |
# | **Content Features**   | **text_content**            | Main text/content of the post                                         |
# |                        | **hashtags**                | Hashtags used to categorize or promote content                        |
# |                        | **mentions**                | Tagged users or brands in the post                                    |
# |                        | **keywords**                | Important keywords extracted from the text                            |
# |                        | **topic_category**          | Category of content (e.g., Product, Pricing, Delivery, Support)       |
# | **Sentiment Analysis** | **sentiment_score**         | Numeric value representing sentiment (positive or negative intensity) |
# |                        | **sentiment_label**         | Overall sentiment (Positive / Negative)                               |
# |                        | **emotion_type**            | Emotion expressed (Happy, Sad, Angry, Confused, Excited)              |
# |                        | **toxicity_score**          | Measures harmful or offensive content level                           |
# | **Engagement Metrics** | **likes_count**             | Number of likes received                                              |
# |                        | **shares_count**            | Number of times the post was shared                                   |
# |                        | **comments_count**          | Number of comments on the post                                        |
# |                        | **impressions**             | Total number of views                                                 |
# |                        | **engagement_rate**         | Overall engagement (interaction level relative to views)              |
# | **Marketing Info**     | **brand_name**              | Brand associated with the post                                        |
# |                        | **product_name**            | Product being discussed                                               |
# |                        | **campaign_name**           | Name of the marketing campaign                                        |
# |                        | **campaign_phase**          | Stage of campaign (Pre-Launch, Launch, Post-Launch)                   |
# | **User Behavior**      | **user_past_sentiment_avg** | Average sentiment of user’s past posts                                |
# |                        | **user_engagement_growth**  | Growth rate of user engagement over time                              |
# |                        | **buzz_change_rate**        | Change in popularity or trending level                                |
#
# This dataset contains social media posts data with:
#
# - User details (who posted, where, language)
# - Content details (text, hashtags, keywords)
# - Sentiment & emotions (positive, negative, happy, angry, etc.)
# - Engagement metrics (likes, shares, comments)
# - Marketing info (brand, product, campaign)
# - User behavior trends
#
# ### Content Features
# - text_content → Actual post text
# - hashtags → Hashtags used in post
# - mentions → Tagged users/accounts
# - keywords → Important words related to content
# - topic_category → Category (Pricing, Product, Delivery, etc.)
#
# ### Sentiment & Emotion
# - sentiment_score → Numeric sentiment value
# - sentiment_label → Positive / Negative
# - emotion_type → Emotion (Happy, Sad, Angry, etc.)
# - toxicity_score → Level of harmful content
#
# ### Engagement Metrics
# - likes_count → Number of likes
# - shares_count → Number of shares
# - comments_count → Number of comments
# - impressions → Total views
# - engagement_rate → Overall engagement
# ### Marketing Information
# - brand_name → Brand (Nike, Google, etc.)
# - product_name → Product name
# - campaign_name → Campaign title
# - campaign_phase → Pre-launch, Launch, Post-launch
#
# ### User Behavior
# - user_past_sentiment_avg → User’s past sentiment
# - user_engagement_growth → Growth in engagement
# - buzz_change_rate → Change in popularity
#
# ### Project Objectives
#
# The main objectives of this project are:
#
# - Understand Data
# - Explore dataset structure and features
# - Analyze Engagement
# - Study how engagement varies across platforms and campaigns
# - Sentiment Analysis
# - Understand how user emotions affect engagement
# - Data Cleaning & Preparation
# - Handle missing values and outliers
# - Build Machine Learning Models
# - Predict engagement rate using different algorithms
# - Model Comparison
# - Find the best model based on performance
# - Business Insights
# - Provide recommendations for better marketing strategies

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#         Import Libraries
#     </h2>
# </div>

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 15px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 15px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#     1. Data Understanding and Exploration
#     </h1>
# </div>

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#       1. Loading Dataset
#     </h2>
# </div>

# %%
df = pd.read_csv("../../Practice/01_python_first/Social Media Engagement Dataset.csv")

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#         Show the first few rows of the datafram:
#     </h2>
# </div>

# %%
df.head()
# Out:
#         post_id            timestamp day_of_week   platform        user_id  \
# 0  kcqbs6hxybia  2024-12-09 11:26:15      Monday  Instagram  user_52nwb0a6
# 1  vkmervg4ioos  2024-07-28 19:59:26      Sunday    Twitter  user_ucryct98
# 2  memhx4o1x6yu  2024-11-23 14:00:12    Saturday     Reddit  user_7rrev126
# 3  bhyo6piijqt9  2024-09-16 04:35:25      Monday    YouTube  user_4mxuq0ax
# 4  c9dkiomowakt  2024-09-05 21:03:01    Thursday    Twitter  user_l1vpox2k
#
#                location language  \
# 0  Melbourne, Australia       pt
# 1          Tokyo, Japan       ru
# 2        Beijing, China       ru
# 3        Lagos, Nigeria       en
# 4       Berlin, Germany       hi
#
#                                         text_content  \
# 0  Just tried the Chromebook from Google. Best pu...
# 1  Just saw an ad for Microsoft Surface Laptop du...
# 2  What's your opinion about Nike's Epic React?  ...
# 3  Bummed out with my new Diet Pepsi from Pepsi! ...
# ...

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#         Show the last few rows of the datafram:
#     </h2>
# </div>

# %%
df.tail()
# Out:
#             post_id            timestamp day_of_week   platform  \
# 11995  vpqni584supc  2025-01-10 07:55:51      Friday  Instagram
# 11996  h8rvov0xym5z  2024-12-04 18:50:38   Wednesday     Reddit
# 11997  14zrjm51ea3y  2024-10-24 19:11:24    Thursday   Facebook
# 11998  7bdmnv3rdj8n  2024-11-12 03:07:19     Tuesday     Reddit
# 11999  28cbflmapxbj  2024-05-15 20:07:23   Wednesday     Reddit
#
#              user_id            location language  \
# 11995  user_ysobum87  Seoul, South Korea       ar
# 11996  user_2jzngfsp       New York, USA       pt
# 11997  user_0sidyfyh        Lyon, France       ja
# 11998  user_njyhr041      Manchester, UK       fr
# 11999  user_gbxy87di        Tokyo, Japan       zh
#
#                                             text_content  \
# 11995  Comparing Toyota Camry to the competition. Bes...
# 11996  My two days review of Apple AirPods Pro: Highl...
# 11997  Just unboxed my new Dri-FIT from Nike. Best pu...
# ...

# %%
# print the shape of the dataset
print("The number of rows:", df.shape[0])
print("The number of columns:", df.shape[1])
# Out:
# The number of rows: 12000
# The number of columns: 28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   post_id                  12000 non-null  object
#  1   timestamp                12000 non-null  object
#  2   day_of_week              12000 non-null  object
#  3   platform                 12000 non-null  object
#  4   user_id                  12000 non-null  object
#  5   location                 12000 non-null  object
#  6   language                 12000 non-null  object
#  7   text_content             12000 non-null  object
#  8   hashtags                 12000 non-null  object
#  9   mentions                 8059 non-null   object
#  10  keywords                 12000 non-null  object
#  11  topic_category           12000 non-null  object
#  12  sentiment_score          12000 non-null  float64
#  13  sentiment_label          12000 non-null  object
# ...

# %%
df.describe().T
# Out:
#                            count          mean           std        min  \
# sentiment_score          12000.0      0.000553      0.583563   -0.99980
# toxicity_score           12000.0      0.503868      0.288198    0.00000
# likes_count              12000.0   2490.720250   1441.532530    0.00000
# shares_count             12000.0   1007.167167    575.072282    0.00000
# comments_count           12000.0    504.345750    288.684160    0.00000
# impressions              12000.0  49811.338500  28930.289451  130.00000
# engagement_rate          12000.0      0.278137      1.149206    0.00188
# user_past_sentiment_avg  12000.0      0.001472      0.576627   -0.99960
# user_engagement_growth   12000.0      0.000998      0.289940   -0.49990
# buzz_change_rate         12000.0      0.729692     57.787219  -99.90000
#
#                                   25%           50%           75%          max
# sentiment_score             -0.503200     -0.006200      0.513525      0.99990
# ...

# %%
df.columns
# Out:
# Index(['post_id', 'timestamp', 'day_of_week', 'platform', 'user_id',
#        'location', 'language', 'text_content', 'hashtags', 'mentions',
#        'keywords', 'topic_category', 'sentiment_score', 'sentiment_label',
#        'emotion_type', 'toxicity_score', 'likes_count', 'shares_count',
#        'comments_count', 'impressions', 'engagement_rate', 'brand_name',
#        'product_name', 'campaign_name', 'campaign_phase',
#        'user_past_sentiment_avg', 'user_engagement_growth',
#        'buzz_change_rate'],
#       dtype='object')

# %%
import skimpy as sk
sk.skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 12000  │ │ string      │ 18    │                                                          │
# │ │ Number of columns │ 28     │ │ float64     │ 6     │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 4     │                                                          │
# ...

# %%
df.dtypes
# Out:
# post_id                     object
# timestamp                   object
# day_of_week                 object
# platform                    object
# user_id                     object
# location                    object
# language                    object
# text_content                object
# hashtags                    object
# mentions                    object
# keywords                    object
# topic_category              object
# sentiment_score            float64
# sentiment_label             object
# emotion_type                object
# toxicity_score             float64
# likes_count                  int64
# shares_count                 int64
# comments_count               int64
# impressions                  int64
# engagement_rate            float64
# brand_name                  object
# product_name                object
# campaign_name               object
# campaign_phase              object
# user_past_sentiment_avg    float64
# user_engagement_growth     float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 15px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 15px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#      2. Exploratory Data Analysis (EDA)
#     </h1>
# </div>

# %%
import matplotlib.pyplot as plt
# Set the style of the plot
plt.style.use('ggplot')
# Create a histogram of the 'Engagement' column
plt.figure(figsize=(10, 6))
plt.hist(df['engagement_rate'], bins=30, color='blue', edgecolor='black')
# Set the title and labels
plt.title('Distribution of Engagement', fontsize=16)
plt.xlabel('Engagement Rate', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
# Show the plot
plt.show()

# %%
# print the platform
print(df['platform'].unique())
# Out:
# ['Instagram' 'Twitter' 'Reddit' 'YouTube' 'Facebook']

# %%
# Don not show the warnings
import warnings
warnings.filterwarnings("ignore")


# the platform  with the highest average engagement rate :
avg_engagement_by_platform = df.groupby('platform')['engagement_rate'].mean()
print(avg_engagement_by_platform)
# Out:
# platform
# Facebook     0.286412
# Instagram    0.287131
# Reddit       0.278727
# Twitter      0.259331
# YouTube      0.279185
# Name: engagement_rate, dtype: float64

# %%
# Create a bar plot to visualize the average engagement rate by platform
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_engagement_by_platform.index, y=avg_engagement_by_platform.values, palette='viridis')
# Set the title and labels
plt.title('Average Engagement Rate by Platform', fontsize=16)
plt.xlabel('Platform', fontsize=14)
plt.ylabel('Average Engagement Rate', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# -  The upper plot is that the platform with the highest average engagement rate is Instagram, followed by Facebook and Twitter. This suggests that content on Instagram tends to receive more interactions (likes, comments, shares) compared to the other platforms in this dataset.
#
# - The higher engagement rate on Instagram could be due to its visual nature, which often encourages more user interaction. Facebook and Twitter, while still popular, may not foster the same level of engagement for the content in this dataset.
#
# - This insight can be valuable for marketers and content creators when deciding where to focus their efforts for maximum engagement.

# %% [markdown]
# ---

# %%
# campaign phase analysis
print(df['campaign_phase'].unique())
print(df['campaign_phase'].value_counts())
# Out:
# ['Launch' 'Post-Launch' 'Pre-Launch']
# campaign_phase
# Pre-Launch     4006
# Launch         4004
# Post-Launch    3990
# Name: count, dtype: int64

# %%
# print the campaign_name
print(df['campaign_name'].unique())
# Out:
# ['BlackFriday' 'PowerRelease' 'LaunchWave' 'LocalTouchpoints'
#  'CyberMonday' 'GlobalCampaign' 'CustomerFirst' 'SpringBlast2025'
#  'HolidaySpecial' 'ValentinesDeals' 'InnovationX' 'WinterWonders'
#  'NewYearNewYou' 'SummerDreams' 'SustainableFuture' 'EarthDay'
#  'BackToSchool' 'DigitalTransformation' 'ReferralBonus' 'SummerSale'
#  'FallCollection' 'LoyaltyRewards' 'NextGeneration']

# %%
# visualize the distribution of campaign phases
plt.figure(figsize=(10, 6))
sns.countplot(x='campaign_phase', data=df, palette='Set2')
# Set the title and labels
plt.title('Distribution of Campaign Phases', fontsize=16)
plt.xlabel('Campaign Phase', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Show the plot
plt.show()

# %%
# print the brand_name
print(df['brand_name'].unique())
# Out:
# ['Google' 'Microsoft' 'Nike' 'Pepsi' 'Toyota' 'Coca-Cola' 'Amazon'
#  'Samsung' 'Adidas' 'Apple']

# %%
# visualize the distribution of brand_name
plt.figure(figsize=(10, 6))
sns.countplot(x='brand_name', data=df, palette='Set3')
# Set the title and labels
plt.title('Distribution of Brand Names', fontsize=16)
plt.xlabel('Brand Name', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# - The heighest average engagement rate is Micrisoft and
# - The second is Addidas and the third is Toyota and
# - The fourth is Nike and the fifth is Amazon and
# - The sixth is Samsung and the seventh is Apple and
# - The eighth is Google and the ninth is Pepsi and the tenth is coca-cola

# %%
# print the product_name
print(df['product_name'].unique())
# Out:
# ['Chromebook' 'Surface Laptop' 'Epic React' 'Diet Pepsi' 'Corolla' 'React'
#  'Pepsi Wild Cherry' 'Coke Zero' 'Pixel Watch' 'Halo Band' 'Pixel Buds'
#  'Crystal Pepsi' 'Galaxy S25' 'Surface Duo' 'Xbox Series X'
#  'Coca-Cola Vanilla' 'Pepsi Max' 'Highlander' 'Predator' 'RAV4'
#  'Xbox Elite Controller' 'Coca-Cola Cherry' 'MacBook Pro' 'iMac'
#  'Ring Camera' 'Nest Hub' 'Sienna' 'Dri-FIT' 'FlyKnit' 'Galaxy Z Fold'
#  'Camry' 'Yeezy' 'Pepsi Lime' 'Echo Dot' 'Ultraboost' 'Fire Tablet'
#  'Samba' 'Apple Watch' 'Fanta' 'Galaxy Buds' 'NMD' 'Prius' 'Pixel Tablet'
#  'iPad Air' 'Nest Thermostat' 'AirPods Pro' 'Air Jordan' 'Tundra'
#  'Stan Smith' 'Zoom Pegasus' 'Tacoma' 'Air Max' 'Sprite' 'Mac Mini'
#  'Neo QLED TV' 'Air Force 1' 'Diet Coke' 'Pixel 8' 'Galaxy Watch'
#  'Surface Go' 'Kindle' 'Gazelle' 'Surface Pro' 'Eero WiFi' 'Vision Pro'
#  'Galaxy Tab' 'Superstar' 'Pepsi Zero Sugar' 'Fire TV' 'iPhone 15']

# %%
print(df['product_name'].value_counts())
# Out:
# product_name
# Coca-Cola Vanilla    226
# Surface Pro          224
# Pepsi Max            216
# Surface Duo          215
# Pepsi Zero Sugar     214
#                     ...
# iMac                 139
# iPhone 15            135
# MacBook Pro          135
# Prius                133
# FlyKnit              129
# Name: count, Length: 70, dtype: int64

# %%
# print the user_past_sentiment_avg
print(df['user_past_sentiment_avg'].unique())
print(df['user_past_sentiment_avg'].value_counts())
# Out:
# [ 0.0953  0.1369  0.2855 ...  0.5936 -0.3666  0.3128]
# user_past_sentiment_avg
#  0.2961    6
# -0.1901    6
#  0.1306    5
# -0.0652    5
#  0.1371    5
#           ..
# -0.3771    1
# -0.1214    1
#  0.2809    1
# -0.3005    1
#  0.3115    1
# Name: count, Length: 9050, dtype: int64

# %%
# visualize the distribution of user_past_sentiment_avg
plt.figure(figsize=(10, 6))
sns.histplot(df['user_past_sentiment_avg'], bins=30, kde=True, color='orange')
# Set the title and labels
plt.title('Distribution of User Past Sentiment Average', fontsize=16)
plt.xlabel('User Past Sentiment Average', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
# Show the plot
plt.show()

# %%
# print the user_engagement_growth
print(df['user_engagement_growth'].unique())
print(df['user_engagement_growth'].value_counts())
# Out:
# [-0.3672 -0.451  -0.4112 ... -0.3351 -0.0412  0.0535]
# user_engagement_growth
# -0.0641    9
#  0.3854    8
#  0.1208    8
# -0.1033    7
# -0.0952    6
#           ..
#  0.3595    1
# -0.3702    1
#  0.0958    1
#  0.3152    1
# -0.3777    1
# Name: count, Length: 6966, dtype: int64

# %%
# visualize the distribution of user_engagement_growth
plt.figure(figsize=(10, 6))
sns.histplot(df['user_engagement_growth'], bins=30, kde=True, color='green')
# Set the title and labels
plt.title('Distribution of User Engagement Growth', fontsize=16)
plt.xlabel('User Engagement Growth', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
# Show the plot
plt.show()

# %%
# print the buzz_change_rate
print(df['buzz_change_rate'].unique())
print(df['buzz_change_rate'].value_counts())
# Out:
# [ 19.1 -42.6  17.4 ...  -9.4  19.   79.4]
# buzz_change_rate
# -13.3    18
# -7.4     14
#  25.8    14
#  1.1     14
#  81.5    14
#          ..
# -78.1     1
#  8.1      1
#  21.7     1
#  19.0     1
#  79.4     1
# Name: count, Length: 1997, dtype: int64

# %%
# visualize the distribution of buzz_change_rate
plt.figure(figsize=(10, 6))
sns.histplot(df['buzz_change_rate'], bins=30, kde=True, color='purple')
# Set the title and labels
plt.title('Distribution of Buzz Change Rate', fontsize=16)
plt.xlabel('Buzz Change Rate', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['post_id', 'timestamp', 'day_of_week', 'platform', 'user_id',
#        'location', 'language', 'text_content', 'hashtags', 'mentions',
#        'keywords', 'topic_category', 'sentiment_score', 'sentiment_label',
#        'emotion_type', 'toxicity_score', 'likes_count', 'shares_count',
#        'comments_count', 'impressions', 'engagement_rate', 'brand_name',
#        'product_name', 'campaign_name', 'campaign_phase',
#        'user_past_sentiment_avg', 'user_engagement_growth',
#        'buzz_change_rate'],
#       dtype='object')

# %%
# print those brand names with the highest average engagement rate
avg_engagement_by_brand = df.groupby('brand_name')['engagement_rate'].mean()
print(avg_engagement_by_brand.sort_values(ascending=False))
# Out:
# brand_name
# Microsoft    0.341136
# Adidas       0.297517
# Toyota       0.296222
# Nike         0.287257
# Amazon       0.284751
# Samsung      0.275804
# Apple        0.273289
# Google       0.256976
# Pepsi        0.238016
# Coca-Cola    0.227559
# Name: engagement_rate, dtype: float64

# %%
# Bar plot for average engagement rate by brand name and x label is Average Engagement Rate and y label is Brand Name and the brand names are sorted by average engagement rate in descending order
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_engagement_by_brand.sort_values(ascending=False).values, y=avg_engagement_by_brand.sort_values(ascending=False).index, palette='coolwarm')
# Set the title and labels
plt.title('Average Engagement Rate by Brand Name', fontsize=16)
plt.xlabel('Average Engagement Rate', fontsize=14)
plt.ylabel('Brand Name', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Brands at the top have the highest engagement rate
# - Brands at the bottom have the lowest engagement rate
# - You can easily compare all brands in one view
#
# ### Key Insight:
# - It helps identify which brand is performing best on social media
# - It also shows which brands need improvement

# %%
# visualize those brand names with the more used the social media platforms and the x label is Platform and the y label is Brand Name and the hue is Brand Name
plt.figure(figsize=(12, 8))
sns.countplot(x='platform', hue='brand_name', data=df, palette='Set1')
# Set the title and labels
plt.title('Brand Name Distribution Across Platforms', fontsize=16)
plt.xlabel('Platform', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Each bar shows how many times a brand appears on a specific platform
# - You can see which brands are more active on which platforms
# - Taller bars mean more posts for that brand on that platform
#
# ### Key Insights:
# - Identify which platform is most used by each brand
# - Compare brand presence across platforms
# - Understand marketing focus of brands (e.g., some brands may focus more on Instagram than Twitter)

# %%
# visualize those product names with the more used the social media platforms 
plt.figure(figsize=(12, 8))
sns.countplot(x='platform', hue='product_name', data=df, palette='Set2')
# Set the title and labels
plt.title('Product Name Distribution Across Platforms', fontsize=16)
plt.xlabel('Platform', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Each colored bar shows how many posts are related to a specific product on a platform
# - You can see which products are more popular or discussed on each platform
# - Taller bars mean that product is mentioned more on that platform
#
# ### Key Insights:
# - Identify which product is most talked about on each platform
# - Compare product popularity across platforms
# - Understand where each product performs best

# %%
# vsiualize those campaign phases with the more used the social media platforms 
plt.figure(figsize=(12, 8))
sns.countplot(x='platform', hue='campaign_phase', data=df, palette='Set3')
# Set the title and labels
plt.title('Campaign Phase Distribution Across Platforms', fontsize=16)
plt.xlabel('Platform', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Show the plot
plt.show()

# %%
# visualize those ten  heigh product names with the more used the social media platforms
top_10_products = df['product_name'].value_counts().nlargest(10).index
plt.figure(figsize=(12, 8))
sns.countplot(x='platform', hue='product_name', data=df[df['product_name'].isin(top_10_products)], palette='Set2')
# Set the title and labels
plt.title('Top 10 Product Name Distribution Across Platforms', fontsize=16)
plt.xlabel('Platform', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Only the top 10 most popular products (based on frequency) are included
# - Each bar shows how often a product appears on a specific platform
# - Taller bars mean that product is discussed more on that platform
#
# ### Key Insights:
# - Identify which top products are trending on each platform
# - Compare product popularity across platforms
# - See which platform is best for promoting specific products

# %%
# visualize those ten most used product names with the more likes_count,and sort the product names by likes_count in descending order
top_10_products = df['product_name'].value_counts().nlargest(10).index
top_10_products_likes = df[df['product_name'].isin(top_10_products)].groupby('product_name')['likes_count'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_products_likes.values, y=top_10_products_likes.index, palette='magma')
# Set the title and labels
plt.title('Average Likes Count for Top 10 Product Names', fontsize=16)
plt.xlabel('Average Likes Count', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Products at the top have the highest average likes
# - Products at the bottom have lower average likes
# - Longer bars mean more likes and higher popularity
#
# ### Key Insights:
# - Identify which products get the most likes
# - Understand which products are most popular among users
# - Helps brands know which products attract more attention

# %%
# visualize those ten most used product names with the more shares_count,and sort the product names by likes_count in descending order
top_10_products_shares = df[df['product_name'].isin(top_10_products)].groupby('product_name')['shares_count'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_products_shares.values, y=top_10_products_shares.index, palette='viridis')
# Set the title and labels
plt.title('Average Shares Count for Top 10 Product Names', fontsize=16)
plt.xlabel('Average Shares Count', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Products at the top have the highest average shares
# - Products at the bottom have fewer shares
# - Longer bars mean more sharing by users
#
# ### Key Insights:
# - Identify which products are shared the most
# - Understand which products go more viral
# - Sharing indicates strong user interest and reach

# %%
# # visualize those ten most used product names with the more comments_count,and sort the product names by likes_count in descending order
top_10_products_comments = df[df['product_name'].isin(top_10_products)].groupby('product_name')['comments_count'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_products_comments.values, y=top_10_products_comments.index, palette='coolwarm')
# Set the title and labels
plt.title('Average Comments Count for Top 10 Product Names', fontsize=16)
plt.xlabel('Average Comments Count', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Products at the top receive the most comments
# - Products at the bottom receive fewer comments
# - Longer bars mean more user discussions
#
# ### Key Insights:
# - Identify which products generate the most conversation
# - Understand which products engage users in discussions
# - Comments show deep engagement (users are interested enough to respond)

# %%
# visualize those ten most used product names with the more impressions,and sort the product names by likes_count in descending order
top_10_products_impressions = df[df['product_name'].isin(top_10_products)].groupby('product_name')['impressions'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_products_impressions.values, y=top_10_products_impressions.index, palette='plasma')
# Set the title and labels
plt.title('Average Impressions for Top 10 Product Names', fontsize=16)
plt.xlabel('Average Impressions', fontsize=14)
plt.ylabel('Product Name', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### What the Visualization Shows:
# - Products at the top have the highest number of views
# - Products at the bottom have fewer views
# - Longer bars mean more visibility and reach
#
#
# ### Key Insights:
# - Identify which products are seen by more users
# - Understand which products have the highest reach
# - High impressions mean strong visibility, even if engagement may vary

# %% [markdown]
# ---

# %%
# correlation heatmap for numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])  # Select only numeric columns
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
# Set the title and labels
plt.title('Correlation Heatmap', fontsize=16)
# Show the plot
plt.show()

# %% [markdown]
# ### How to Read the Heatmap:
#
# - Each box (cell) shows the correlation value between two variables
# - Values range from -1 to +1:
# - +1 → Strong positive relationship (both increase together)
# - 0 → No relationship
# - -1 → Strong negative relationship (one increases, other decreases)
#
# ### Colors:
# - 🔴 Red = Positive correlation
# - 🔵 Blue = Negative correlation
# - White/light = Weak or no correlation
# ### Point-wise Explanation:
# 1. Engagement Metrics Relationship
# - likes_count, shares_count, comments_count
# - Usually strong positive correlation
# - If likes increase, shares and comments also increase
# 2. Impressions vs Engagement
# - impressions vs likes/shares/comments
# - Often moderate positive correlation
# - More views = more chances of interaction
# 3. Engagement Rate
# - engagement_rate vs likes/shares/comments
# - Positive correlation
# -  Higher interactions increase engagement rate
# 4. Sentiment Score
# - sentiment_score vs engagement metrics
# - Can be positive or weak
# - Positive posts may get more engagement, but not always
# 5. Toxicity Score
# - toxicity_score vs engagement
# - Sometimes positive or mixed
# -  Controversial posts can also get attention
# 6. User Behavior Features
# - user_past_sentiment_avg & user_engagement_growth
# - Show moderate relationships
# -  Past behavior influences current engagement
# 7. Buzz Change Rate
# - buzz_change_rate vs engagement
# - Usually positive
# -  Trending topics get more interaction
# ### Key Insights:
# - Engagement metrics (likes, shares, comments) are strongly connected
# - Impressions help increase engagement
# - Sentiment and toxicity have mixed effects
# - Useful for feature selection in machine learning

# %% [markdown]
# ---

# %%
# sentiment relationships.
plt.figure(figsize=(10, 8))
sns.scatterplot(x='likes_count', y='sentiment_score', data=df, hue='platform', palette='Set1')
# Set the title and labels
plt.title('Sentiment Relationship with Likes Count', fontsize=16)
plt.xlabel('Likes Count', fontsize=14)
plt.ylabel('Sentiment Score', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### 1. Overall Pattern
# - If most points are scattered without a clear upward or downward slope, then likes and sentiment are not strongly correlated.
# - If points trend upward (more likes → higher sentiment), it indicates positive correlation.
# - If points trend downward, it indicates negative correlation.
# ### 2. Platform Comparison (Hue)
# - Each platform is colored differently, so you can see platform-specific trends.
# - Example scenarios:
# - Twitter posts may cluster at lower likes but show a wide sentiment range → less correlation.
# - Facebook posts may cluster with higher likes and higher sentiment → positive correlation.
# ### 3. Outliers
# - Very high likes with extreme sentiment (positive or negative) can skew your perception.
# - You might notice a few posts with viral likes that dominate the right side.
# ### 4. Likely Conclusion
#
# Based on typical social media data:
#
# - Weak to moderate correlation overall.
# - Some platforms might show stronger trends than others (e.g., posts on Instagram might get more likes when sentiment is positive).
# - No strong universal rule: likes are influenced by many factors beyond sentiment (timing, content type, hashtags, etc.).

# %% [markdown]
# ---

# %%
# visualize the relationship between sentiment_label and engagement_rate
plt.figure(figsize=(10, 8))
sns.boxplot(x='sentiment_label', y='engagement_rate', data=df, palette='Set2')
# Set the title and labels
plt.title('Engagement Rate by Sentiment Label', fontsize=16)
plt.xlabel('Sentiment Label', fontsize=14)
plt.ylabel('Engagement Rate', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### How to interpret relationships
# Compare medians:
# - If the median for Positive is higher than Neutral or Negative, positive posts tend to have higher engagement.
# - Compare IQR width:
# - Wider boxes → engagement rates vary more for that sentiment.
# - Narrow boxes → more consistent engagement.
# - Look for outliers:
# - Extremely high engagement posts might indicate viral posts regardless of sentiment.
# ### Likely Insights
# - Positive sentiment posts usually get higher median engagement.
# - Negative sentiment posts might have more variability, with some posts going viral and others getting ignored.
# - Neutral posts tend to have moderate, consistent engagement.

# %% [markdown]
# ---

# %%
# visualize the relationship between emotion_type and engagement_rate
plt.figure(figsize=(10, 8))
sns.boxplot(x='emotion_type', y='engagement_rate', data=df, palette='Set3')
# Set the title and labels
plt.title('Engagement Rate by Emotion Type', fontsize=16)
plt.xlabel('Emotion Type', fontsize=14)
plt.ylabel('Engagement Rate', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### Emotion Type vs Engagement Rate (Boxplot)
# - What it shows: The boxplot illustrates engagement rates for posts based on the specific emotion expressed (e.g., joy, sadness, surprise, anger).
# - Why it matters: Helps understand which emotions resonate most with audiences and drive interaction.
# ### Visual insights:
# - Positive/attention-grabbing emotions like joy or surprise tend to get higher engagement.
# - Negative or intense emotions like sadness or anger show more variability; some posts may go viral, but many receive lower engagement.
# - Emotion type is a key factor influencing audience interaction.
#
# - Sentiment and emotion both influence engagement: Positive sentiment and certain positive emotions tend to drive higher engagement.
# - Platform and content type matter: Trends can vary by platform or post type, suggesting a one-size-fits-all strategy won’t work.
# - High variability for negative emotions: While some posts with negative sentiment/emotions can go viral, most receive lower engagement.

# %% [markdown]
# ---
