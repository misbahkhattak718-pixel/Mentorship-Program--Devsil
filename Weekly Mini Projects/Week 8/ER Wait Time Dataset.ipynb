# %% [markdown]
# <div style="background-color:#FAF3F3; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #E57373; margin-top: 20px;">
#     <h1 style="font-size:28px; font-family:Georgia, serif; color:#D32F2F; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         Exploratory Data Analysis and Machine Learning on ER Wait Time Dataset
#     </h1>
# </div>

# %% [markdown]
# <div style="background-color:#E6F9E6; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 20px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#4A90E2; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#         About Author
#     </h1>
#     <div style="text-align:center;">
#         <a href="https://misbah.devsil.com/">
#             <img src="https://misbah.devsil.com/assets/images/picture%20misbah.png" style="width: 20%; border-radius: 50%;" alt="Misbah Khattak">
#         </a>
#     </div>
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333; text-align:center;">Mr. Misbah Khattak</h2>
#     <p style="font-size:16px; font-family:Georgia, serif; line-height: 1.5em; text-align:center; color:#333;">
#         <em>Data Scientist / AI Engineer</em><br>
#         BS Computer Science
#     </p>
#     <div style="text-align:center; margin-top: 10px;">
#         <a href="https://www.linkedin.com/mynetwork/grow/">
#             <img width="50" height="50" src="https://img.icons8.com/color/48/linkedin.png" alt="linkedin">
#         </a>
#         <a href="https://github.com/misbahkhattak718-pixel?tab=repositories">
#             <img width="50" height="50" src="https://img.icons8.com/ios-glyphs/50/github.png" alt="github">
#         </a>
#         <a href="https://www.kaggle.com/misbahkhattak123">
#             <img width="50" height="50" src="https://img.icons8.com/clouds/100/kaggle.png" alt="kaggle">
#         </a>
#     </div>
#     <div style="text-align:center; margin-top: 20px;">
#         <a href="https://misbah.devsil.com/" style="font-size:18px; font-family:Georgia, serif; color:#4A90E2; text-decoration:none; border:2px solid #4A90E2; padding: 5px 15px; border-radius: 5px;">
#             Portfolio Site
#         </a>
#     </div>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Project Table of Contents</title>
#     <style>
#         table {
#             width: 100%;
#             border-collapse: collapse;
#             font-family: Arial, sans-serif;
#         }
#         th, td {
#             border: 1px solid #333;
#             padding: 8px;
#             text-align: left;
#         }
#         th {
#             background-color: #2c3e50;
#             color: white;
#         }
#         tr:nth-child(even) {
#             background-color: #f2f2f2;
#         }
#         h2 {
#             text-align: center;
#         }
#     </style>
# </head>
#
# <body>
#
# <h2>Project Table of Contents</h2>
#
# <table>
# <thead>
# <tr>
# <th>No.</th>
# <th>Section</th>
# <th>Subsection</th>
# <th>Description</th>
# </tr>
# </thead>
#
# <tbody>
#
# <tr>
# <td>1</td>
# <td>Introduction</td>
# <td>1.1 Project Background</td>
# <td>Overview of emergency room waiting time analysis</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>1.2 Project Objectives</td>
# <td>Goals of the analysis and prediction task</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>1.3 Dataset Description</td>
# <td>Description of variables and dataset structure</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>1.4 Tools and Technologies</td>
# <td>Python, Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn</td>
# </tr>
#
# <tr>
# <td>2</td>
# <td>Data Cleaning and Preparation</td>
# <td>2.1 Loading the Dataset</td>
# <td>Importing dataset into Jupyter Notebook</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>2.2 Checking Missing Values</td>
# <td>Identifying and handling missing data</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>2.3 Removing Duplicate Records</td>
# <td>Detecting and removing duplicate rows</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>2.4 Date and Time Conversion</td>
# <td>Converting date/time columns into correct format</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>2.5 Creating Time Features</td>
# <td>Creating Hour, Day, and Month columns</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>2.6 Creating Age Groups</td>
# <td>Categorizing patients into age groups</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>2.7 Outlier Detection</td>
# <td>Identifying outliers using statistical methods</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>2.8 Outlier Handling</td>
# <td>Treating or removing extreme values</td>
# </tr>
#
# <tr>
# <td>3</td>
# <td>Exploratory Data Analysis (EDA)</td>
# <td>3.1 Total Number of Patients</td>
# <td>Calculating total patient visits</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.2 Average Waiting Time</td>
# <td>Mean waiting time analysis</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.3 Median Waiting Time</td>
# <td>Median waiting time calculation</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.4 Variance and Standard Deviation</td>
# <td>Measuring variability of waiting time</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.5 Waiting Time Distribution</td>
# <td>Histogram and distribution analysis</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.6 Patient Distribution by Hour</td>
# <td>Hourly patient visit analysis</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.7 Patient Distribution by Weekday</td>
# <td>Day-wise visit analysis</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.8 Waiting Time by Age Group</td>
# <td>Comparing waiting times across age groups</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.9 Waiting Time by Gender</td>
# <td>Gender-based waiting time analysis</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.10 Waiting Time by Triage Level</td>
# <td>Severity level impact on waiting time</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>3.11 Visualization Set</td>
# <td>At least 15 meaningful charts with titles and labels</td>
# </tr>
#
# <tr>
# <td>4</td>
# <td>Statistical Reasoning</td>
# <td>4.1 Group Comparison</td>
# <td>Comparing waiting time between two groups</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>4.2 Mean vs Median Analysis</td>
# <td>Determining which measure better represents the data</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>4.3 Skewness Analysis</td>
# <td>Understanding distribution shape</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>4.4 Correlation Analysis</td>
# <td>Studying relationships between numerical variables</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>4.5 Correlation Heatmap</td>
# <td>Visualizing correlations between features</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>4.6 Interpretation of Results</td>
# <td>Explaining important statistical findings</td>
# </tr>
#
# <tr>
# <td>5</td>
# <td>Feature Engineering</td>
# <td>5.1 Creating New Features</td>
# <td>Generating useful predictive features</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>5.2 Time-Based Features</td>
# <td>Hour, weekday, month related features</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>5.3 Grouped Categories</td>
# <td>Creating grouped patient categories</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>5.4 Encoding Categorical Variables</td>
# <td>Label Encoding or One-Hot Encoding</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>5.5 Dataset Preparation</td>
# <td>Preparing final dataset for machine learning</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>5.6 Feature Importance Explanation</td>
# <td>Explaining usefulness of each feature</td>
# </tr>
#
# <tr>
# <td>6</td>
# <td>Machine Learning Modeling</td>
# <td>6.1 Problem Definition</td>
# <td>Defining prediction goal (waiting time prediction)</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>6.2 Train-Test Split</td>
# <td>Dividing dataset into training and testing sets</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>6.3 Linear Regression Model</td>
# <td>Training and prediction</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>6.4 Decision Tree Model</td>
# <td>Training and prediction</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>6.5 Random Forest Model</td>
# <td>Training and prediction</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>6.6 Model Comparison</td>
# <td>Comparing model performance</td>
# </tr>
#
# <tr>
# <td>7</td>
# <td>Model Evaluation</td>
# <td>7.1 Evaluation Metrics</td>
# <td>MAE, MSE, RMSE, R² for regression</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>7.2 Model Performance Results</td>
# <td>Performance comparison table</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>7.3 Confusion Matrix</td>
# <td>Accuracy, Precision, Recall, F1 Score (if classification)</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>7.4 Best Model Selection</td>
# <td>Identifying the best performing model</td>
# </tr>
#
# <tr>
# <td>8</td>
# <td>Business Recommendations</td>
# <td>8.1 Peak Emergency Room Hours</td>
# <td>Identifying busiest time periods</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>8.2 Longest Waiting Patients</td>
# <td>Patient groups with longest wait</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>8.3 Key Factors Increasing Waiting Time</td>
# <td>Important influencing variables</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>8.4 Staffing Improvement Strategies</td>
# <td>Staff allocation recommendations</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>8.5 Waiting Time Reduction Strategies</td>
# <td>Process improvement suggestions</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>8.6 Operational Improvements</td>
# <td>Practical hospital management ideas</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>8.7 Resource Optimization</td>
# <td>Better use of hospital resources</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>8.8 Final Recommendations</td>
# <td>Eight actionable solutions</td>
# </tr>
#
# <tr>
# <td>9</td>
# <td>Conclusion</td>
# <td>9.1 Summary of Findings</td>
# <td>Key insights from analysis</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>9.2 Project Limitations</td>
# <td>Limitations of dataset and models</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>9.3 Future Improvements</td>
# <td>Suggestions for future work</td>
# </tr>
#
# <tr>
# <td>10</td>
# <td>Final Submission Requirements</td>
# <td>10.1 Jupyter Notebook</td>
# <td>Complete notebook with code and explanations</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>10.2 Cleaned Dataset</td>
# <td>Processed dataset file</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>10.3 Trained Model File</td>
# <td>Saved model (.pkl or .joblib)</td>
# </tr>
#
# <tr>
# <td></td>
# <td></td>
# <td>10.4 Executive Summary</td>
# <td>Two-page project summary</td>
# </tr>
#
# </tbody>
# </table>
#
# </body>
# </html>

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 15px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 15px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#          Introduction
#     </h1>
# </div>

# %% [markdown]
# ### 1. Introduction
#
# ***1.1 Project Background***
#
# Emergency departments play a critical role in providing immediate medical care to patients with urgent health conditions. However, one of the most common challenges faced by hospitals is the long waiting time for patients before they receive medical attention. Long waiting times can lead to patient dissatisfaction, overcrowding, and reduced quality of healthcare services.
#
# This project focuses on analyzing emergency room waiting time using hospital visit data. By studying factors such as urgency level, nurse-to-patient ratio, specialist availability, and facility size, the project aims to understand the reasons behind longer waiting times. Data analysis and machine learning techniques are used to identify patterns and predict waiting time so that hospitals can improve their services and reduce delays.
#
# ---
#
# ***1.2 Project Objectives***
#
# The main objective of this project is to analyze and predict patient waiting time in emergency departments using data analysis and machine learning techniques.
#
# The specific objectives of the project are:
#
# To clean and prepare the dataset for analysis.
#
# To explore the dataset and understand patient waiting time patterns.
#
# To analyze how different factors such as urgency level, hospital size, and staffing affect waiting time.
#
# To create meaningful visualizations that explain patient flow and waiting time distribution.
#
# To build machine learning models that can predict total waiting time for patients.
#
# To evaluate and compare the performance of different machine learning models.
#
# To provide practical recommendations that can help hospitals reduce waiting time and improve patient satisfaction.
#
# ---
#
# ***1.3 Dataset Description***
#
# The dataset used in this project contains information about emergency room visits from multiple hospitals. Each record in the dataset represents a single patient visit and includes details about the hospital, patient visit time, waiting stages, staffing conditions, and patient outcomes.
#
# The dataset contains several important variables such as:
#
# | No. | Variable Name                      | Description                                                                            |
# | --- | ---------------------------------- | -------------------------------------------------------------------------------------- |
# | 1   | Visit ID                           | Unique identifier for each hospital visit.                                             |
# | 2   | Patient ID                         | Unique identifier for each patient.                                                    |
# | 3   | Hospital ID                        | Unique identifier assigned to each hospital.                                           |
# | 4   | Hospital Name                      | Name of the hospital where the patient visit occurred.                                 |
# | 5   | Region                             | Indicates whether the hospital is located in an **Urban** or **Rural** area.           |
# | 6   | Visit Date                         | Date and time when the patient arrived at the hospital.                                |
# | 7   | Day of Week                        | Day when the hospital visit occurred (e.g., Monday, Tuesday).                          |
# | 8   | Season                             | Season of the visit such as Winter, Spring, Summer, or Fall.                           |
# | 9   | Time of Day                        | Indicates whether the visit occurred in the **Morning, Afternoon, Evening, or Night**. |
# | 10  | Urgency Level                      | Severity level of the patient’s medical condition (Low, Medium, High).                 |
# | 11  | Nurse-to-Patient Ratio             | Number of nurses available relative to the number of patients.                         |
# | 12  | Specialist Availability            | Number of specialist doctors available during the visit.                               |
# | 13  | Facility Size (Beds)               | Total number of beds available in the hospital.                                        |
# | 14  | Time to Registration (min)         | Time taken for the patient to complete the registration process.                       |
# | 15  | Time to Triage (min)               | Time taken for the patient to be assessed by triage staff.                             |
# | 16  | Time to Medical Professional (min) | Time taken before the patient sees a doctor or medical professional.                   |
# | 17  | Total Wait Time (min)              | Total waiting time from arrival until medical treatment begins.                        |
# | 18  | Patient Outcome                    | Final result of the visit such as **Discharged or Admitted**.                          |
# | 19  | Patient Satisfaction               | Rating given by the patient regarding their hospital experience.                       |
#
#
# ---
#
# ***1.4 Tools and Technologies***
#
# Several data analysis and machine learning tools are used in this project to process and analyze the dataset effectively.
#
# The main tools and technologies used are:
#
# - Python – The main programming language used for data analysis and machine learning.
#
# - Pandas – Used for data cleaning, manipulation, and dataset preparation.
#
# - NumPy – Used for numerical operations and statistical calculations.
#
# - Matplotlib – Used to create basic data visualizations such as line charts and histograms.
#
# - Seaborn – Used to create advanced and visually appealing statistical plots.
#
# - Scikit-learn – Used to build and evaluate machine learning models such as Linear Regression, Decision Tree, and Random Forest.
#
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#         Import Libraries
#     </h2>
# </div>

# %%
# import libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 15px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 15px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#      2. Data Cleaning & Preprocessing
#     </h1>
# </div>

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#       1. Loading Dataset
#     </h2>
# </div>

# %%
df = pd.read_csv("../../Practice/01_python_first/ER Wait Time Dataset.csv")

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#         Show the first few rows of the datafram:
#     </h2>
# </div>

# %%
df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region           Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban  2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural  2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural  2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban  2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban  2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#         Show the last few rows of the datafram:
#     </h2>
# </div>

# %%
df.tail()
# Out:
#                   Visit ID Patient ID Hospital ID  \
# 4995  HOSP-5-20241212-0989  PAT-04996      HOSP-5
# 4996  HOSP-4-20240630-0995  PAT-04997      HOSP-4
# 4997  HOSP-2-20240213-1022  PAT-04998      HOSP-2
# 4998  HOSP-2-20240828-1023  PAT-04999      HOSP-2
# 4999  HOSP-1-20240825-0994  PAT-05000      HOSP-1
#
#                      Hospital Name Region           Visit Date Day of Week  \
# 4995          Summit Health Center  Urban  2024-12-12 04:29:36    Thursday
# 4996    St. Mary’s Regional Health  Rural  2024-06-30 22:44:17      Sunday
# 4997      Riverside Medical Center  Urban  2024-02-13 21:06:17     Tuesday
# 4998      Riverside Medical Center  Urban  2024-08-28 03:11:51   Wednesday
# 4999  Springfield General Hospital  Urban  2024-08-25 23:05:40      Sunday
#
#       Season Time of Day Urgency Level  Nurse-to-Patient Ratio  \
# 4995  Winter     Evening      Critical                       2
# 4996  Summer     Evening        Medium                       4
# ...

# %%
# print the rows and columns:
print(f"The number of rows: {df.shape[0]}")
print(f"The number of columns: {df.shape[1]}")
# Out:
# The number of rows: 5000
# The number of columns: 19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Visit ID                            5000 non-null   object
#  1   Patient ID                          5000 non-null   object
#  2   Hospital ID                         5000 non-null   object
#  3   Hospital Name                       5000 non-null   object
#  4   Region                              5000 non-null   object
#  5   Visit Date                          5000 non-null   object
#  6   Day of Week                         5000 non-null   object
#  7   Season                              5000 non-null   object
#  8   Time of Day                         5000 non-null   object
#  9   Urgency Level                       5000 non-null   object
#  10  Nurse-to-Patient Ratio              5000 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                                      count     mean        std   min   25%  \
# Nurse-to-Patient Ratio              5000.0   3.2382   1.200895   1.0   3.0
# Specialist Availability             5000.0   3.8750   3.043292   0.0   1.0
# Facility Size (Beds)                5000.0  87.1188  57.998585  10.0  36.0
# Time to Registration (min)          5000.0  11.7042  10.437284   0.0   3.0
# Time to Triage (min)                5000.0  24.8270  24.807994   1.0   6.0
# Time to Medical Professional (min)  5000.0  45.3854  35.619975   2.0  17.0
# Total Wait Time (min)               5000.0  81.9166  68.084538   4.0  27.0
# Patient Satisfaction                5000.0   2.7716   1.424584   1.0   1.0
#
#                                      50%    75%    max
# Nurse-to-Patient Ratio               3.0    4.0    5.0
# Specialist Availability              3.0    6.0   10.0
# Facility Size (Beds)                74.0  138.0  200.0
# Time to Registration (min)           8.0   18.0   66.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     2.2 Checking Missing Values
#     </h2>
# </div>

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Visit ID                              0
# Patient ID                            0
# Hospital ID                           0
# Hospital Name                         0
# Region                                0
# Visit Date                            0
# Day of Week                           0
# Season                                0
# Time of Day                           0
# Urgency Level                         0
# Nurse-to-Patient Ratio                0
# Specialist Availability               0
# Facility Size (Beds)                  0
# Time to Registration (min)            0
# Time to Triage (min)                  0
# Time to Medical Professional (min)    0
# Total Wait Time (min)                 0
# Patient Outcome                       0
# Patient Satisfaction                  0
# dtype: int64

# %% [markdown]
# ### There are no missing values.

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     2.3 Removing Duplicate Records
#     </h2>
# </div>

# %%
# check the duplicates rows:
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### There are no duplicates rows.

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     2.4 Date and Time Conversion
#     </h2>
# </div>

# %%
# Converting date/time columns into correct format:
df['Visit Date'] = pd.to_datetime(df['Visit Date'])

# Extracting month, day, year from Visit Date column:
df['Month'] = df['Visit Date'].dt.month
df['Day'] = df['Visit Date'].dt.day
df['Year'] = df['Visit Date'].dt.year

# %%
# show the dataset:
df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region          Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban 2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural 2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural 2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban 2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban 2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     2.5 Creating Time Features
#     </h2>
# </div>

# %%
# Creating Hour, Day, and Month columns:
df['Hour'] = df['Visit Date'].dt.hour
df['Day'] = df['Visit Date'].dt.day
df['Month'] = df['Visit Date'].dt.month

# %%
df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region          Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban 2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural 2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural 2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban 2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban 2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     2.7 Outlier Detection
#     </h2>
# </div>

# %%
# Identifying outliers using statistical methods:
df.describe().T
# Out:
#                                      count                           mean  \
# Visit Date                            5000  2024-06-30 11:59:40.381599744
# Nurse-to-Patient Ratio              5000.0                         3.2382
# Specialist Availability             5000.0                          3.875
# Facility Size (Beds)                5000.0                        87.1188
# Time to Registration (min)          5000.0                        11.7042
# Time to Triage (min)                5000.0                         24.827
# Time to Medical Professional (min)  5000.0                        45.3854
# Total Wait Time (min)               5000.0                        81.9166
# Patient Satisfaction                5000.0                         2.7716
# Month                               5000.0                          6.463
# Day                                 5000.0                        15.7928
# Year                                5000.0                         2024.0
# ...

# %%
# don't show the warning:
import warnings
warnings.filterwarnings('ignore')

# visualize the outlier in the dataset using boxplot:

plt.figure(figsize=(20, 20))

# Only include numeric columns for boxplot visualization
numeric_cols = df.select_dtypes(include=[np.number]).columns

re = 1
for i in numeric_cols:
    plt.subplot(len(numeric_cols) // 4 + 1, 4, re)
    sns.boxplot(x=df[i], palette="Set2")
    plt.title(i)
    re += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#D0E6F3; padding: 15px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1); border:2px solid #66C2A5; margin-top: 15px;">
#     <h1 style="font-size:24px; font-family:Georgia, serif; color:#000000; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">
#     3.  Exploratory Data Analysis(EDA)
#     </h1>
# </div

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.1 Total Number of Patients
#     </h2>
# </div>

# %%
df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region          Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban 2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural 2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural 2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban 2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban 2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %%
# print the total number of patients of the dataset:
print(f"The total numbers of patient is : {df['Patient ID'].nunique()}")

# Print the total number of Urban and Rural patients:
print(f"The total number of Urban patients is : {df[df['Region'] == 'Urban']['Patient ID'].nunique()}")
print(f"The total number of Rural patients is : {df[df['Region'] == 'Rural']['Patient ID'].nunique()}")
# Out:
# The total numbers of patient is : 5000
# The total number of Urban patients is : 3006
# The total number of Rural patients is : 1994

# %%
# Print the hospital name and total number of patients step by step:
hospital_patient_count = df.groupby('Hospital Name')['Patient ID'].nunique()
for hospital, count in hospital_patient_count.items():
	print(f"Hospital Name: {hospital}, Total Number of Patients: {count}")
# Out:
# Hospital Name: Northside Community Hospital, Total Number of Patients: 999
# Hospital Name: Riverside Medical Center, Total Number of Patients: 1023
# Hospital Name: Springfield General Hospital, Total Number of Patients: 994
# Hospital Name: St. Mary’s Regional Health, Total Number of Patients: 995
# Hospital Name: Summit Health Center, Total Number of Patients: 989

# %%
# Print the total number of patients in each season:
season_patient_count = df.groupby('Season')['Patient ID'].nunique()
for season, count in season_patient_count.items():
    print(f"Season: {season}, Total Number of Patients: {count}")
# Out:
# Season: Fall, Total Number of Patients: 1234
# Season: Spring, Total Number of Patients: 1227
# Season: Summer, Total Number of Patients: 1281
# Season: Winter, Total Number of Patients: 1258

# %% [markdown]
# ### OUTPUT
#
# - The total numbers of patient is : 2329
# - The total number of Urban patients is : 880
# - The total number of Rural patients is : 1449
#
# - Hospital Name: Northside Community Hospital, Total Number of Patients: 718
# - Hospital Name: Riverside Medical Center, Total Number of Patients: 309
# - Hospital Name: Springfield General Hospital, Total Number of Patients: 292
# - Hospital Name: St. Mary’s Regional Health, Total Number of Patients: 731
# - Hospital Name: Summit Health Center, Total Number of Patients: 279
#
# - Season: Fall, Total Number of Patients: 586
# - Season: Spring, Total Number of Patients: 570
# - Season: Summer, Total Number of Patients: 600
# - Season: Winter, Total Number of Patients: 573

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.2 Average Waiting Time
#     </h2>
# </div>

# %%
# Mean waiting time analysis:
print(f"Mean waiting time for all patients: {df['Time to Triage (min)'].mean()}")
print(f"Mean waiting time for Urban patients: {df[df['Region'] == 'Urban']['Time to Triage (min)'].mean()}")
print(f"Mean waiting time for Rural patients: {df[df['Region'] == 'Rural']['Time to Triage (min)'].mean()}")
# Out:
# Mean waiting time for all patients: 24.827
# Mean waiting time for Urban patients: 24.708250166334
# Mean waiting time for Rural patients: 25.00601805416249

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.3 Median Waiting Time
#     </h2>
# </div>

# %%
# calculate the median waiting time:
median_waiting_time = df['Time to Triage (min)'].median()
print(f"The median waiting time for all patients is: {median_waiting_time}")
# Out:
# The median waiting time for all patients is: 16.0

# %%
# calculate  the mode of waiting time:
mode_waiting_time = df['Time to Triage (min)'].mode()
print(f"The mode waiting time for all patients is: {mode_waiting_time}")
# Out:
# The mode waiting time for all patients is: 0    3
# Name: Time to Triage (min), dtype: int64

# %%
# calculate the standard deviation of waiting time:
std_waiting_time = df['Time to Triage (min)'].std()
print(f"The standard deviation of waiting time for all patients is: {std_waiting_time}")
# Out:
# The standard deviation of waiting time for all patients is: 24.80799383891536

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.4 Variance and Standard Deviation
#     </h2>
# </div>

# %%
# calculate the variance and standard deviation of waiting time:
var_waiting_time = df['Time to Triage (min)'].var()
std_waiting_time = df['Time to Triage (min)'].std()

print(f"The variance of waiting time for all patients is: {var_waiting_time}")
print(f"The standard deviation of waiting time for all patients is: {std_waiting_time}")
# Out:
# The variance of waiting time for all patients is: 615.4365583116625
# The standard deviation of waiting time for all patients is: 24.80799383891536

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.5 Waiting Time Distribution
#     </h2>
# </div>

# %%
# Measuring variability of waiting time analysis:
plt.figure(figsize=(10, 6))
sns.histplot(df['Time to Triage (min)'], kde=True, color='blue', bins=30)
plt.title('Distribution of Waiting Time (Time to Triage)', fontsize=16)
plt.xlabel('Time to Triage (min)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.6 Patient Distribution by Hour
#     </h2>
# </div>

# %%
# Hourly patient visit analysis Distribution by Hour:

hourly_distribution = df['Hour'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
hourly_distribution.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Hourly Patient Visit Distribution', fontsize=16)
plt.xlabel('Hour of the Day', fontsize=12)
plt.ylabel('Number of Patients', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df.Hour
# Out:
# 0       20
# 1        2
# 2        4
# 3        0
# 4       16
#         ..
# 4995     4
# 4996    22
# 4997    21
# 4998     3
# 4999    23
# Name: Hour, Length: 5000, dtype: int32

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.7 Patient Distribution by Weekday
#     </h2>
# </div>

# %%
# Patient Distribution by Day-wise visit analysis:

day_distribution = df['Day'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
day_distribution.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Day-wise Patient Visit Distribution', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Number of Patients', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.8 Waiting Time by Age Group
#     </h2>
# </div>

# %%
df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region          Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban 2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural 2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural 2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban 2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban 2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %%
# Create a random age column between 1 and 90
df['Age'] = np.random.randint(1, 90, size=len(df))

df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region          Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban 2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural 2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural 2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban 2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban 2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# 6     75
# 54    74
# 72    69
# 49    68
# 77    67
#       ..
# 20    46
# 26    46
# 2     45
# 65    45
# 61    41
# Name: count, Length: 89, dtype: int64

# %%
df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region          Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban 2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural 2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural 2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban 2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban 2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %%
# check the outlier in Age column:
df['Age'].describe()
# Out:
# count    5000.000000
# mean       44.998200
# std        25.720165
# min         1.000000
# 25%        23.000000
# 50%        45.000000
# 75%        67.000000
# max        89.000000
# Name: Age, dtype: float64

# %%
# Comparing waiting times across age groups:
waiting_time_by_age = df.groupby('Age')['Time to Registration (min)'].mean()
plt.figure(figsize=(20, 6))
waiting_time_by_age.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Waiting Time by Age Group', fontsize=16)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Average Waiting Time (min)', fontsize=12)
plt.xticks(rotation=30)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# rotate the x-axis labels 45 degrees:

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.9 Waiting Time by Gender
#     </h2>
# </div>

# %%
# Create Gender column with random Male/Female values
df['Gender'] = np.random.choice(['Male', 'Female'], size=len(df))

df.head()
# Out:
#                Visit ID Patient ID Hospital ID                 Hospital Name  \
# 0  HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# 1  HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# 2  HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# 3  HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# 4  HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
#
#   Region          Visit Date Day of Week  Season   Time of Day Urgency Level  \
# 0  Urban 2024-02-10 20:20:56    Saturday  Winter  Late Morning        Medium
# 1  Rural 2024-11-28 02:07:47    Thursday    Fall       Evening        Medium
# 2  Rural 2024-09-30 04:02:28      Monday    Fall       Evening           Low
# 3  Urban 2024-02-27 00:31:13     Tuesday  Winter       Evening          High
# 4  Urban 2024-03-06 16:52:26   Wednesday  Spring     Afternoon           Low
#
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    2502
# Male      2498
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df)

plt.title("Patient Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Patients")

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Gender', y='Total Wait Time (min)', data=df)

plt.title("Waiting Time by Gender")
plt.xlabel("Gender")
plt.ylabel("Total Waiting Time")

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="background-color:#E6F2FF; padding: 10px; border-radius: 8px; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1); border:1px solid #66C2A5; margin-top: 10px; margin-left: 20px;">
#     <h2 style="font-size:20px; font-family:Georgia, serif; color:#333333; text-align: left; margin: 0;">
#     3.10 Visualization Set
#     </h2>
# </div>

# %% [markdown]
# ### Patient Visits by Day of Week

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Day of Week'], order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title("Patient Visits by Day of Week")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Waiting Time by Urgency Level

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Urgency Level', y='Total Wait Time (min)', data=df)
plt.title("Waiting Time by Urgency Level")
plt.show()

# %%
# print the number of patient of each urgency level:
urgency_level_patient_count = df.groupby('Urgency Level')['Patient ID'].nunique()
for urgency_level, count in urgency_level_patient_count.items():
    print(f"Urgency Level: {urgency_level}, Total Number of Patients: {count}")
# Out:
# Urgency Level: Critical, Total Number of Patients: 1242
# Urgency Level: High, Total Number of Patients: 1245
# Urgency Level: Low, Total Number of Patients: 1222
# Urgency Level: Medium, Total Number of Patients: 1291

# %% [markdown]
# ### Average Waiting Time by Hour

# %%
hourly_wait = df.groupby('Hour')['Total Wait Time (min)'].mean()

plt.figure(figsize=(8,5))
hourly_wait.plot(kind='line', marker='o')
plt.title("Average Waiting Time by Hour")
plt.xlabel("Hour")
plt.ylabel("Average Waiting Time")
plt.show()

# %%
import plotly.express as px

# Create a scatter plot using Plotly Express
fig = px.scatter(df, x='Hour', y='Total Wait Time (min)', color='Urgency Level', title='Waiting Time by Hour and Urgency Level')
fig.show()

# %%
import plotly.express as px

fig = px.histogram(df, x="Total Wait Time (min)", title="Waiting Time Distribution")


fig.show()

# %% [markdown]
# ### Patient Outcome Distribution

# %%
plt.figure(figsize=(6,6))
df['Patient Outcome'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Patient Outcome Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Waiting Time vs Facility Size

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Facility Size (Beds)', y='Total Wait Time (min)', data=df)
plt.title("Waiting Time vs Facility Size")
plt.show()

# %%
# Create a scatter plot using Plotly Express
fig = px.scatter(df, x='Facility Size (Beds)', y='Total Wait Time (min)', title='Waiting Time vs Facility Size')
fig.show()

# %% [markdown]
# ### Waiting Time vs Nurse-to-Patient Ratio

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Nurse-to-Patient Ratio', y='Total Wait Time (min)', data=df)
plt.title("Waiting Time vs Nurse-to-Patient Ratio")
plt.show()

# %% [markdown]
# - The Waiting Time vs Nurse-to-Patient Ratio is that the higher the nurse-to-patient ratio, the higher the waiting time.

# %% [markdown]
# ### Monthly Patient Visits

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Month', data=df)
plt.title("Patient Visits by Month")
plt.show()

# %% [markdown]
# ### Waiting Time by Season

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Season', y='Total Wait Time (min)', data=df)
plt.title("Waiting Time by Season")
plt.show()

# %% [markdown]
# - The winter season is patient is more wait time than other season reason is that the winter season is cold season and people are more sick
#  than other season

# %%
# print the number of patient of each season:
season_patient_count = df.groupby('Season')['Patient ID'].nunique()
for season, count in season_patient_count.items():
    print(f"Season: {season}, Total Number of Patients: {count}")
# Out:
# Season: Fall, Total Number of Patients: 1234
# Season: Spring, Total Number of Patients: 1227
# Season: Summer, Total Number of Patients: 1281
# Season: Winter, Total Number of Patients: 1258

# %%
# print the number of patient of each month:
month_patient_count = df.groupby('Month')['Patient ID'].nunique()
for month, count in month_patient_count.items():
    print(f"Month: {month}, Total Number of Patients: {count}")
# Out:
# Month: 1, Total Number of Patients: 436
# Month: 2, Total Number of Patients: 418
# Month: 3, Total Number of Patients: 398
# Month: 4, Total Number of Patients: 427
# Month: 5, Total Number of Patients: 402
# Month: 6, Total Number of Patients: 429
# Month: 7, Total Number of Patients: 419
# Month: 8, Total Number of Patients: 433
# Month: 9, Total Number of Patients: 415
# Month: 10, Total Number of Patients: 432
# Month: 11, Total Number of Patients: 387
# Month: 12, Total Number of Patients: 404

# %%
# print the number of patient of each day of week:
day_of_week_patient_count = df.groupby('Day of Week')['Patient ID'].nunique()
for day_of_week, count in day_of_week_patient_count.items():
    print(f"Day of Week: {day_of_week}, Total Number of Patients: {count}")
# Out:
# Day of Week: Friday, Total Number of Patients: 685
# Day of Week: Monday, Total Number of Patients: 768
# Day of Week: Saturday, Total Number of Patients: 701
# Day of Week: Sunday, Total Number of Patients: 725
# Day of Week: Thursday, Total Number of Patients: 706
# Day of Week: Tuesday, Total Number of Patients: 741
# Day of Week: Wednesday, Total Number of Patients: 674

# %%
# print the number of patient of each hour:
hour_patient_count = df.groupby('Hour')['Patient ID'].nunique()
for hour, count in hour_patient_count.items():
    print(f"Hour: {hour}, Total Number of Patients: {count}")
# Out:
# Hour: 0, Total Number of Patients: 228
# Hour: 1, Total Number of Patients: 218
# Hour: 2, Total Number of Patients: 194
# Hour: 3, Total Number of Patients: 171
# Hour: 4, Total Number of Patients: 182
# Hour: 5, Total Number of Patients: 219
# Hour: 6, Total Number of Patients: 213
# Hour: 7, Total Number of Patients: 206
# Hour: 8, Total Number of Patients: 221
# Hour: 9, Total Number of Patients: 215
# Hour: 10, Total Number of Patients: 231
# Hour: 11, Total Number of Patients: 228
# Hour: 12, Total Number of Patients: 197
# Hour: 13, Total Number of Patients: 212
# Hour: 14, Total Number of Patients: 213
# Hour: 15, Total Number of Patients: 199
# Hour: 16, Total Number of Patients: 219
# Hour: 17, Total Number of Patients: 181
# Hour: 18, Total Number of Patients: 205
# Hour: 19, Total Number of Patients: 217
# Hour: 20, Total Number of Patients: 205
# Hour: 21, Total Number of Patients: 227
# Hour: 22, Total Number of Patients: 213
# Hour: 23, Total Number of Patients: 186

# %%
# print the number of patient of each month:
urgency_level_patient_count = df.groupby('Urgency Level')['Patient ID'].nunique()
for urgency_level, count in urgency_level_patient_count.items():
    print(f"Urgency Level: {urgency_level}, Total Number of Patients: {count}")
# Out:
# Urgency Level: Critical, Total Number of Patients: 1242
# Urgency Level: High, Total Number of Patients: 1245
# Urgency Level: Low, Total Number of Patients: 1222
# Urgency Level: Medium, Total Number of Patients: 1291

# %%
# print the number of patient of each month:
region_patient_count = df.groupby('Region')['Patient ID'].nunique()
for region, count in region_patient_count.items():
    print(f"Region: {region}, Total Number of Patients: {count}")
# Out:
# Region: Rural, Total Number of Patients: 1994
# Region: Urban, Total Number of Patients: 3006

# %% [markdown]
# ---
